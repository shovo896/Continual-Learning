# %%
import torch 
import torch.nn as nn
import torch.optim as optim

# %%
model=nn.Sequential(
       nn.Linear(2,20),
       nn.ReLU(),
       nn.Linear(20,2)
)
optimizer=optim.SGD(model.parameters(),lr=0.01)
